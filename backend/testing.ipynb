# %%
tools = ["hii","hello"]
tools.__len__()
# Out:
# 2

# %%
res = {'success': True, 
'data': {'get_purchase_orders': 
{'success': True, 'data': 
{'items': [], 'count': 0, 'hasMore': False, 'limit': 10, 'offset': 0, 'links': [{'rel': 'self', 'href': 'https://fa-eqkx-dev4-saasfaprod1.fa.ocs.oraclecloud.com:443/fscmRestApi/resources/11.13.18.05/purchaseOrders', 'name': 'purchaseOrders', 'kind': 'collection'}]}}}}
